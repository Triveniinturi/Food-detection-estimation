# %%
# !nvidia-smi
# Out:
# Sat Oct 18 03:42:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   43C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="e66HMh7BHgVY4KnP7TOa")
project = rf.workspace("fooddetectionyolov8-bhli3").project("indianfoodnet-c0mxe")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 138.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to IndianFoodNet-1 in yolov8:: 100%|██████████| 10904/10904 [00:02<00:00, 4553.25it/s]

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 40.7/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo mode=train model=yolov8s.pt data=/content/IndianFoodNet-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 96.0MB/s]
# New https://pypi.org/project/ultralytics/8.3.217 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !git init
# !git config --global user.name "Triveniinturi"
# !git config --global user.email "triveniinturi7@gmail.com"
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git clone git@github.com:Triveniinturi/Food-detection-estimation.git
# Out:
# fatal: destination path 'Food-detection-estimation' already exists and is not an empty directory.

# %%
# !git clone git@github.com:Triveniinturi/Food-detection-estimation.git
# Out:
# fatal: destination path 'Food-detection-estimation' already exists and is not an empty directory.

# %%
# %cd Food-detection-estimation
# Out:
# /content/Food-detection-estimation

# %%
# %mv /content/yolov8n.pt /content/Food-detection-estimation
# %mv /content/yolov8s.pt /content/Food-detection-estimation
# Out:
# mv: cannot stat '/content/yolov8n.pt': No such file or directory
# mv: cannot stat '/content/yolov8s.pt': No such file or directory

# %%
# Move data.yaml
# %mv /content/IndianFoodNet-1/data.yaml /content/Food-detection-estimation/

# Move the Python scripts
# %mv /content/train.py /content/Food-detection-estimation/
# %mv /content/test.py /content/Food-detection-estimation/
# %mv /content/detect.py /content/Food-detection-estimation/
# %mv /content/predict.py /content/Food-detection-estimation/

# Move the 'runs' directory
# %mv /content/runs /content/Food-detection-estimation/

# Move readme
# %mv /content/IndianFoodNet-1/README.dataset.txt /content/Food-detection-estimation/
# %mv /content/IndianFoodNet-1/README.roboflow.txt /content/Food-detection-estimation/
# Out:
# mv: cannot stat '/content/IndianFoodNet-1/data.yaml': No such file or directory
# mv: cannot stat '/content/train.py': No such file or directory
# mv: cannot stat '/content/test.py': No such file or directory
# mv: cannot stat '/content/detect.py': No such file or directory
# mv: cannot stat '/content/predict.py': No such file or directory
# mv: cannot stat '/content/runs': No such file or directory
# mv: cannot stat '/content/IndianFoodNet-1/README.dataset.txt': No such file or directory
# mv: cannot stat '/content/IndianFoodNet-1/README.roboflow.txt': No such file or directory

# %%
# !git add /content/Food-detection-estimation/yolov8n.pt
# !git add /content/Food-detection-estimation/yolov8s.pt
# !git add /content/Food-detection-estimation/data.yaml
# !git add /content/Food-detection-estimation/train.py
# !git add /content/Food-detection-estimation/test.py
# !git add /content/Food-detection-estimation/detect.py
# !git add /content/Food-detection-estimation/predict.py
# !git add /content/Food-detection-estimation/runs/
# !git add /content/Food-detection-estimation/README.dataset.txt
# !git add /content/Food-detection-estimation/README.roboflow.txt
# Out:
# fatal: pathspec '/content/Food-detection-estimation/train.py' did not match any files
# fatal: pathspec '/content/Food-detection-estimation/test.py' did not match any files
# fatal: pathspec '/content/Food-detection-estimation/detect.py' did not match any files
# fatal: pathspec '/content/Food-detection-estimation/predict.py' did not match any files

# %%
# !git status
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Initial commit with project structure and 100 epoch (yolov8s.pt data=/content/IndianFoodNet-1/data.yaml epochs=100 imgsz=640)"
# !git branch -M main
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %%
# !git remote -v
# Out:
# origin	https://github.com/Triveniinturi/Food-detection-estimation (fetch)
# origin	https://github.com/Triveniinturi/Food-detection-estimation (push)

# %%
# !git remote set-url origin https://github.com/Triveniinturi/Food-detection-estimation.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/Triveniinturi/Food-detection-estimation.git (fetch)
# origin	https://github.com/Triveniinturi/Food-detection-estimation.git (push)

# %%
# !git remote set-url origin https://Triveniinturi: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@github.com/Triveniinturi/Food-detection-estimation.git

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 37, done.
# Counting objects: 100% (37/37), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (35/35), done.
# Writing objects: 100% (37/37), 72.22 MiB | 10.84 MiB/s, done.
# Total 37 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Triveniinturi/Food-detection-estimation.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
